# %%
library(tidyverse)

df <- read_csv("https://raw.githubusercontent.com/petebrown/scrape-results-playwright/main/data/records.csv", show_col_types = FALSE)

results <- read_csv("https://raw.githubusercontent.com/petebrown/update-results/main/data/results_df.csv", show_col_types = FALSE)

venues <- read_csv("https://raw.githubusercontent.com/petebrown/update-results/main/data/results_df.csv", show_col_types = FALSE) %>%
    rename(game_url = source_url) %>%
    select(game_url, venue)

# %%
df2 <- df %>%
    left_join(venues, by = "game_url") %>%
    mutate(
        game_date = lubridate::dmy(game_date),
        ko_time = str_match(match_notes, "(?:[Kk]ick[\\s|-][Oo]ff:\\s)(\\d+.\\d+[a|p]m)")[,2],
    ) %>%
    mutate(
        competition_2 = str_replace(competition_2, "Associate Members' Cup", "Associate Members Cup"),
        cup_stage = str_match(competition_2, str_glue("{competition}\\s(.*)"))[,2],
        cup_round_no = str_match(competition_2, "(\\d+).*\\sround")[,2],
        cup_round = case_when(
            str_detect(cup_stage, regex("quarter-final", ignore_case = TRUE)) ~ "QF",
            str_detect(cup_stage, regex("semi-final", ignore_case = TRUE)) ~ "SF",
            str_detect(cup_stage, regex("^final", ignore_case = TRUE)) ~ "F",
            str_detect(cup_stage, regex("preliminary", ignore_case = TRUE)) ~ "P",
            str_detect(cup_stage, regex("group", ignore_case = TRUE)) ~ "G",
            .default = cup_round_no
        ),
        cup_replay = case_when(
            grepl("\\sreplay", competition_2, ignore.case = TRUE) ~ 1,
            TRUE ~ 0
        ),
        cup_section = case_when(
            str_detect(cup_stage, regex("\\s([a-zA-Z]+)\\s[Ss]ection")) ~ str_match(str_to_title(cup_stage), "\\s([a-zA-Z]+)\\s[Ss]ection")[,2],
            str_detect(cup_stage, regex("Group\\s[a-zA-Z]\\s–\\s[a-zA-Z]+")) ~ str_match(str_to_title(cup_stage), "(Group\\s[a-zA-Z]\\s–\\s[a-zA-Z]+)")[,2],
            .default = NA
        ),
        cup_leg = str_match(competition_2, "(\\d+)[a-zA-Z]+\\sleg")[,2]
    ) %>%
    mutate(
        extra_time = case_when(
            grepl("after extra time", match_notes, ignore.case = TRUE) ~ 1,
            TRUE ~ 0)
    ) %>%
    mutate(
        penalties = case_when(
            grepl("penalt", score_2, ignore.case = TRUE) ~ str_match(score_2, "(?:[Pp]enalties\\s)(\\d+-\\d+ to\\s.+)"),
            grepl("penalt", match_notes, ignore.case = FALSE) ~ str_match(match_notes, "(?:penalty\\sshoot[-|\\s]out\\s)\\((\\d+-\\d+)\\)"),
            grepl("PENALT", match_notes, ignore.case = FALSE) ~ str_match(match_notes, "(?:[^|\\|].+\\sWON\\s)(\\d+-\\d+)(?:\\sON\\sPENALTIES)"),
            .default = NA)[,2],
        pen_winners = case_when(
            grepl("\\d+-\\d+ to", penalties, ignore.case = TRUE) ~ str_match(penalties, "\\d+-\\d+\\sto\\s(.*)")[,2],
            grepl("were awarded a bonus point", match_notes, ignore.case = TRUE) ~ str_match(match_notes, ",\\s(.*)\\swere\\sawarded\\sa\\sbonus\\spoint")[,2],
            grepl("won \\d+-\\d+ on penalties", match_notes, ignore.case = TRUE) ~ str_match(str_to_title(match_notes), "(([a-zA-Z]+\\s)?[a-zA-Z]+)\\sWon\\s\\d+-\\d+\\sOn\\sPenalties")[,2],
            TRUE ~ NA
        ),
        pen_score = case_when(
            is.na(pen_winners) ~ NA,
            !grepl("Tranmere", pen_winners, ignore.case = TRUE) ~ paste0(str_match(penalties, "-(\\d+)")[,2], "-", str_match(penalties, "(\\d+)-")[,2]),
            TRUE ~ str_match(penalties, "(\\d+-\\d+)")[,2]),
        pen_outcome = case_when(
            is.na(pen_winners) ~ NA,
            grepl("Tranmere", pen_winners, ignore.case = TRUE) ~ "W",
            !grepl("Tranmere", pen_winners, ignore.case = TRUE) ~ "L"
        ),
        pen_gf = case_when(
            !is.na(pen_score) & venue == "H" ~ str_match(pen_score, "(\\d+)-")[,2],
            !is.na(pen_score) & venue == "A" ~ str_match(pen_score, "-(\\d+)")[,2],
            .default = NA
        ),
        pen_ga = case_when(
            !is.na(pen_score) & venue == "H" ~ str_match(pen_score, "-(\\d+)")[,2],
            !is.na(pen_score) & venue == "A" ~ str_match(pen_score, "(\\d+)-")[,2],
            .default = NA
        ),
        pen_gf = as.numeric(pen_gf),
        pen_ga = as.numeric(pen_ga),
    ) %>%
    mutate(
        agg_score = case_when(
            grepl("on aggregate", match_notes, ignore.case = TRUE) ~ str_match(match_notes, "(\\d+-\\d+)\\son\\saggregate")[,2],
            grepl("agg:", score, ignore.case = TRUE) ~ str_match(score, "[Aa]gg:\\s?(\\d+-\\d+)")[,2],
            .default = NA
          ),
        agg_winners = str_match(match_notes, "(([a-zA-Z]+\\s)?[a-zA-Z]+)\\swon\\s\\d+-\\d+\\son\\saggregate")[,2],
        agg_outcome = case_when(
            cup_leg == "2" & is.na(agg_winners) & !is.na(agg_score) ~ "D",
            cup_leg == "2" & !is.na(agg_winners) & str_detect(agg_winners, regex("Tranmere", ignore_case = TRUE)) ~ "W",
            cup_leg == "2" & !is.na(agg_winners) & str_detect(agg_winners, regex("Tranmere", ignore_case = TRUE), negate = TRUE) ~ "L",
            .default = NA),
        agg_score = case_when(
            agg_outcome == "D" ~ agg_score,
            agg_outcome == "W" ~ agg_score,
            agg_outcome == "L" ~ paste0(str_sub(agg_score, 3, 3), "-", str_sub(agg_score, 1, 1)),
            .default = NA
        )
    ) %>%
    mutate(
        away_goals_winner = str_match(match_notes, "(([a-zA-Z]+\\s)?[a-zA-Z]+)\\swon\\son\\sthe\\saway\\sgoals\\srule")[,2],
        away_goal_outcome = case_when(
            is.na(away_goals_winner) ~ NA,
            grepl("Tranmere", away_goals_winner, ignore.case = TRUE) ~ "W",
            !grepl("Tranmere", away_goals_winner, ignore.case = TRUE) ~ "L"
        )
    ) %>%
    mutate(
        cup_leg = case_when(
            !is.na(agg_outcome) & is.na(cup_leg) ~ "2",
            .default = cup_leg
        )
    ) %>%
    mutate(
        agg_gf = case_when(
            cup_leg == "2" & is.na(agg_winners) & !is.na(agg_score) & venue == "H" ~ str_match(agg_score, "(\\d+)-")[,2],
            cup_leg == "2" & is.na(agg_winners) & !is.na(agg_score) & venue == "A" ~ str_match(agg_score, "-(\\d+)")[,2],
            .default = NA
        ),
        agg_ga = case_when(
            cup_leg == "2" & is.na(agg_winners) & !is.na(agg_score) & venue == "H" ~ str_match(agg_score, "-(\\d+)")[,2],
            cup_leg == "2" & is.na(agg_winners) & !is.na(agg_score) & venue == "A" ~ str_match(agg_score, "(\\d+)-")[,2],
            .default = NA
        ),
        agg_gf = as.numeric(agg_gf),
        agg_ga = as.numeric(agg_ga),
        agg_outcome = case_when(
            agg_gf > agg_ga ~ "W",
            agg_gf < agg_ga ~ "L",
            agg_gf == agg_ga ~ "D",
            .default = agg_outcome
        ),
        agg_score = case_when(
            agg_outcome == "W" & venue == "A" ~ paste0(str_sub(agg_score, 3, 3), "-", str_sub(agg_score, 1, 1)),
            .default = agg_score
        ),
    ) %>%
    select(
        game_url,
        ko_time,
        cup_round, cup_leg, cup_stage, cup_replay, cup_section, 
        extra_time,
        pen_outcome, pen_score, pen_gf, pen_ga,
        agg_outcome, agg_score, agg_gf, agg_ga,
        away_goal_outcome
    )

# %%
df_left <- results %>%
    rename(game_url = source_url)

df_right <- df2

# %%
df_left %>%
    inner_join(df_right, by = "game_url")
# Out:
#      season  game_date  opposition         venue score home_team
# 1    2022/23 2023-03-25 Colchester United  A     1-1   Colchester United
# 2    2022/23 2023-03-18 Newport County     H     1-3   Tranmere Rovers
# 3    2022/23 2023-03-11 Gillingham         A     0-2   Gillingham
# 4    2022/23 2023-03-04 Hartlepool United  H     1-1   Tranmere Rovers
# 5    2022/23 2023-02-28 Crawley Town       H     1-0   Tranmere Rovers
# 6    2022/23 2023-02-25 Stevenage          A     1-0   Stevenage
# 7    2022/23 2023-02-18 Mansfield Town     H     0-2   Tranmere Rovers
# 8    2022/23 2023-02-14 Bradford City      A     0-2   Bradford City
# 9    2022/23 2023-02-11 Salford City       H     1-0   Tranmere Rovers
# 10   2022/23 2023-02-07 Doncaster Rovers   A     0-2   Doncaster Rovers
# 11   2022/23 2023-02-04 Stockport County   A     2-3   Stockport County
# 12   2022/23 2023-01-28 Leyton Orient      H     1-0   Tranmere Rovers
# 13   2022/23 2023-01-14 Walsall            H     1-1   Tranmere Rovers
# 14   2022/23 2023-01-07 Sutton United      H     2-2   Tranmere Rovers
# 15   2022/23 2023-01-01 Crewe Alexandra    A     0-1   Crewe Alexandra
# 16   2022/23 2022-12-29 Barrow             A     2-1   Barrow
# 17   2022/23 2022-12-26 Doncaster Rovers   H     3-0   Tranmere Rovers
# 18   2022/23 2022-12-10 Grimsby Town       A     1-2   Grimsby Town
# 19   2022/23 2022-12-03 Northampton Town   A     0-0   Northampton Town
# 20   2022/23 2022-11-22 Burton Albion      A     1-1   Burton Albion
# 21   2022/23 2022-11-19 AFC Wimbledon      H     0-2   Tranmere Rovers
# 22   2022/23 2022-11-12 Swindon Town       A     1-1   Swindon Town
# 23   2022/23 2022-11-05 Carlisle United    A     1-2   Carlisle United
# 24   2022/23 2022-11-01 Stockport County   H     0-0   Tranmere Rovers
# 25   2022/23 2022-10-29 Carlisle United    H     0-2   Tranmere Rovers
# 26   2022/23 2022-10-25 Rochdale           H     1-1   Tranmere Rovers
# 27   2022/23 2022-10-22 Harrogate Town     A     1-1   Harrogate Town
# 28   2022/23 2022-10-18 Crewe Alexandra    A     1-0   Crewe Alexandra
# 29   2022/23 2022-10-14 Crewe Alexandra    H     3-0   Tranmere Rovers
# 30   2022/23 2022-10-08 Sutton United      A     2-0   Sutton United
# ⋮    ⋮       ⋮          ⋮                  ⋮     ⋮     ⋮
# 4653 1921/22 1922-04-01 Durham City        H     3-3   Tranmere Rovers
# 4654 1921/22 1922-03-25 Barrow             A     0-2   Barrow
# 4655 1921/22 1922-03-18 Barrow             H     2-2   Tranmere Rovers
# 4656 1921/22 1922-03-04 Ashington          A     0-1   Ashington
# 4657 1921/22 1922-02-25 Lincoln City       H     4-0   Tranmere Rovers
# 4658 1921/22 1922-02-18 Lincoln City       A     1-4   Lincoln City
# 4659 1921/22 1922-02-11 Darlington         H     0-1   Tranmere Rovers
# 4660 1921/22 1922-02-04 Darlington         A     0-4   Darlington
# 4661 1921/22 1922-01-28 Accrington Stanley A     0-3   Accrington Stanley
# 4662 1921/22 1922-01-21 Accrington Stanley H     2-4   Tranmere Rovers
# 4663 1921/22 1922-01-14 Grimsby Town       A     1-5   Grimsby Town
# 4664 1921/22 1921-12-31 Grimsby Town       H     2-2   Tranmere Rovers
# 4665 1921/22 1921-12-27 Hartlepools United H     1-2   Tranmere Rovers
# 4666 1921/22 1921-12-26 Ashington          H     2-3   Tranmere Rovers
# 4667 1921/22 1921-12-24 Stockport County   A     0-0   Stockport County
# 4668 1921/22 1921-12-17 Stockport County   H     0-2   Tranmere Rovers
# 4669 1921/22 1921-12-10 Southport          A     1-1   Southport
# 4670 1921/22 1921-11-26 Hartlepools United A     0-0   Hartlepools United
# 4671 1921/22 1921-11-12 Wigan Borough      H     2-0   Tranmere Rovers
# 4672 1921/22 1921-11-05 Wigan Borough      A     0-0   Wigan Borough
# 4673 1921/22 1921-10-29 Stalybridge Celtic A     0-4   Stalybridge Celtic
# 4674 1921/22 1921-10-22 Stalybridge Celtic H     4-1   Tranmere Rovers
# 4675 1921/22 1921-10-15 Rochdale           H     7-0   Tranmere Rovers
# 4676 1921/22 1921-10-08 Rochdale           A     1-2   Rochdale
# 4677 1921/22 1921-10-01 Halifax Town       A     2-0   Halifax Town
# 4678 1921/22 1921-09-24 Halifax Town       H     2-2   Tranmere Rovers
# 4679 1921/22 1921-09-17 Walsall            A     0-2   Walsall
# 4680 1921/22 1921-09-10 Walsall            H     0-1   Tranmere Rovers
# 4681 1921/22 1921-09-03 Crewe Alexandra    A     1-1   Crewe Alexandra
# 4682 1921/22 1921-08-27 Crewe Alexandra    H     4-1   Tranmere Rovers
#      away_team          outcome home_goals away_goals ⋯ extra_time pen_outcome
# 1    Tranmere Rovers    D       1          1          ⋯ 0          NA
# 2    Newport County     L       1          3          ⋯ 0          NA
# 3    Tranmere Rovers    L       2          0          ⋯ 0          NA
# 4    Hartlepool United  D       1          1          ⋯ 0          NA
# 5    Crawley Town       W       1          0          ⋯ 0          NA
# 6    Tranmere Rovers    W       0          1          ⋯ 0          NA
# 7    Mansfield Town     L       0          2          ⋯ 0          NA
# 8    Tranmere Rovers    L       2          0          ⋯ 0          NA
# 9    Salford City       W       1          0          ⋯ 0          NA
# 10   Tranmere Rovers    L       2          0          ⋯ 0          NA
# 11   Tranmere Rovers    L       3          2          ⋯ 0          NA
# 12   Leyton Orient      W       1          0          ⋯ 0          NA
# 13   Walsall            D       1          1          ⋯ 0          NA
# 14   Sutton United      D       2          2          ⋯ 0          NA
# 15   Tranmere Rovers    L       1          0          ⋯ 0          NA
# 16   Tranmere Rovers    W       1          2          ⋯ 0          NA
# 17   Doncaster Rovers   W       3          0          ⋯ 0          NA
# 18   Tranmere Rovers    L       2          1          ⋯ 0          NA
# 19   Tranmere Rovers    D       0          0          ⋯ 0          NA
# 20   Tranmere Rovers    L       1          1          ⋯ 0          L
# 21   AFC Wimbledon      L       0          2          ⋯ 0          NA
# 22   Tranmere Rovers    D       1          1          ⋯ 0          NA
# 23   Tranmere Rovers    L       2          1          ⋯ 0          NA
# 24   Stockport County   D       0          0          ⋯ 0          NA
# 25   Carlisle United    L       0          2          ⋯ 0          NA
# 26   Rochdale           D       1          1          ⋯ 0          NA
# 27   Tranmere Rovers    D       1          1          ⋯ 0          NA
# 28   Tranmere Rovers    W       0          1          ⋯ 0          NA
# 29   Crewe Alexandra    W       3          0          ⋯ 0          NA
# 30   Tranmere Rovers    W       0          2          ⋯ 0          NA
# ⋮    ⋮                  ⋮       ⋮          ⋮          ⋱ ⋮          ⋮
# 4653 Durham City        D       3          3          ⋯ 0          NA
# 4654 Tranmere Rovers    L       2          0          ⋯ 0          NA
# 4655 Barrow             D       2          2          ⋯ 0          NA
# 4656 Tranmere Rovers    L       1          0          ⋯ 0          NA
# 4657 Lincoln City       W       4          0          ⋯ 0          NA
# 4658 Tranmere Rovers    L       4          1          ⋯ 0          NA
# 4659 Darlington         L       0          1          ⋯ 0          NA
# 4660 Tranmere Rovers    L       4          0          ⋯ 0          NA
# 4661 Tranmere Rovers    L       3          0          ⋯ 0          NA
# 4662 Accrington Stanley L       2          4          ⋯ 0          NA
# 4663 Tranmere Rovers    L       5          1          ⋯ 0          NA
# 4664 Grimsby Town       D       2          2          ⋯ 0          NA
# 4665 Hartlepools United L       1          2          ⋯ 0          NA
# 4666 Ashington          L       2          3          ⋯ 0          NA
# 4667 Tranmere Rovers    D       0          0          ⋯ 0          NA
# 4668 Stockport County   L       0          2          ⋯ 0          NA
# 4669 Tranmere Rovers    D       1          1          ⋯ 0          NA
# 4670 Tranmere Rovers    D       0          0          ⋯ 0          NA
# 4671 Wigan Borough      W       2          0          ⋯ 0          NA
# 4672 Tranmere Rovers    D       0          0          ⋯ 0          NA
# 4673 Tranmere Rovers    L       4          0          ⋯ 0          NA
# 4674 Stalybridge Celtic W       4          1          ⋯ 0          NA
# 4675 Rochdale           W       7          0          ⋯ 0          NA
# 4676 Tranmere Rovers    L       2          1          ⋯ 0          NA
# 4677 Tranmere Rovers    W       0          2          ⋯ 0          NA
# 4678 Halifax Town       D       2          2          ⋯ 0          NA
# 4679 Tranmere Rovers    L       2          0          ⋯ 0          NA
# 4680 Walsall            L       0          1          ⋯ 0          NA
# 4681 Tranmere Rovers    D       1          1          ⋯ 0          NA
# 4682 Crewe Alexandra    W       4          1          ⋯ 0          NA
#      pen_score pen_gf pen_ga agg_outcome agg_score agg_gf agg_ga
# 1    NA        NA     NA     NA          NA        NA     NA
# 2    NA        NA     NA     NA          NA        NA     NA
# 3    NA        NA     NA     NA          NA        NA     NA
# 4    NA        NA     NA     NA          NA        NA     NA
# 5    NA        NA     NA     NA          NA        NA     NA
# 6    NA        NA     NA     NA          NA        NA     NA
# 7    NA        NA     NA     NA          NA        NA     NA
# 8    NA        NA     NA     NA          NA        NA     NA
# 9    NA        NA     NA     NA          NA        NA     NA
# 10   NA        NA     NA     NA          NA        NA     NA
# 11   NA        NA     NA     NA          NA        NA     NA
# 12   NA        NA     NA     NA          NA        NA     NA
# 13   NA        NA     NA     NA          NA        NA     NA
# 14   NA        NA     NA     NA          NA        NA     NA
# 15   NA        NA     NA     NA          NA        NA     NA
# 16   NA        NA     NA     NA          NA        NA     NA
# 17   NA        NA     NA     NA          NA        NA     NA
# 18   NA        NA     NA     NA          NA        NA     NA
# 19   NA        NA     NA     NA          NA        NA     NA
# 20   4-5        5      4     NA          NA        NA     NA
# 21   NA        NA     NA     NA          NA        NA     NA
# 22   NA        NA     NA     NA          NA        NA     NA
# 23   NA        NA     NA     NA          NA        NA     NA
# 24   NA        NA     NA     NA          NA        NA     NA
# 25   NA        NA     NA     NA          NA        NA     NA
# 26   NA        NA     NA     NA          NA        NA     NA
# 27   NA        NA     NA     NA          NA        NA     NA
# 28   NA        NA     NA     NA          NA        NA     NA
# 29   NA        NA     NA     NA          NA        NA     NA
# 30   NA        NA     NA     NA          NA        NA     NA
# ⋮    ⋮         ⋮      ⋮      ⋮           ⋮         ⋮      ⋮
# 4653 NA        NA     NA     NA          NA        NA     NA
# 4654 NA        NA     NA     NA          NA        NA     NA
# 4655 NA        NA     NA     NA          NA        NA     NA
# 4656 NA        NA     NA     NA          NA        NA     NA
# 4657 NA        NA     NA     NA          NA        NA     NA
# 4658 NA        NA     NA     NA          NA        NA     NA
# 4659 NA        NA     NA     NA          NA        NA     NA
# 4660 NA        NA     NA     NA          NA        NA     NA
# 4661 NA        NA     NA     NA          NA        NA     NA
# 4662 NA        NA     NA     NA          NA        NA     NA
# 4663 NA        NA     NA     NA          NA        NA     NA
# 4664 NA        NA     NA     NA          NA        NA     NA
# 4665 NA        NA     NA     NA          NA        NA     NA
# 4666 NA        NA     NA     NA          NA        NA     NA
# 4667 NA        NA     NA     NA          NA        NA     NA
# 4668 NA        NA     NA     NA          NA        NA     NA
# 4669 NA        NA     NA     NA          NA        NA     NA
# 4670 NA        NA     NA     NA          NA        NA     NA
# 4671 NA        NA     NA     NA          NA        NA     NA
# 4672 NA        NA     NA     NA          NA        NA     NA
# 4673 NA        NA     NA     NA          NA        NA     NA
# 4674 NA        NA     NA     NA          NA        NA     NA
# 4675 NA        NA     NA     NA          NA        NA     NA
# 4676 NA        NA     NA     NA          NA        NA     NA
# 4677 NA        NA     NA     NA          NA        NA     NA
# 4678 NA        NA     NA     NA          NA        NA     NA
# 4679 NA        NA     NA     NA          NA        NA     NA
# 4680 NA        NA     NA     NA          NA        NA     NA
# 4681 NA        NA     NA     NA          NA        NA     NA
# 4682 NA        NA     NA     NA          NA        NA     NA
#      away_goal_outcome
# 1    NA
# 2    NA
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    NA
# 8    NA
# 9    NA
# 10   NA
# 11   NA
# 12   NA
# 13   NA
# 14   NA
# 15   NA
# 16   NA
# 17   NA
# 18   NA
# 19   NA
# 20   NA
# 21   NA
# 22   NA
# 23   NA
# 24   NA
# 25   NA
# 26   NA
# 27   NA
# 28   NA
# 29   NA
# 30   NA
# ⋮    ⋮
# 4653 NA
# 4654 NA
# 4655 NA
# 4656 NA
# 4657 NA
# 4658 NA
# 4659 NA
# 4660 NA
# 4661 NA
# 4662 NA
# 4663 NA
# 4664 NA
# 4665 NA
# 4666 NA
# 4667 NA
# 4668 NA
# 4669 NA
# 4670 NA
# 4671 NA
# 4672 NA
# 4673 NA
# 4674 NA
# 4675 NA
# 4676 NA
# 4677 NA
# 4678 NA
# 4679 NA
# 4680 NA
# 4681 NA
# 4682 NA
